# %% [markdown]
# # CORE

# %%
import numpy as np
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
from copy import deepcopy

# %%
# %config InlineBackend.figure_format='retina'
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (16, 12)
import matplotlib.pyplot as plt

# %%
from CarlaBEV.envs.utils import load_map

rgbmap, _, _ = load_map(size=1024)

print(f"Image Size: {rgbmap.shape}")
# Out:
# Image Size: (10240, 8192, 3)

# %%
# Check map
plt.imshow(rgbmap)
plt.show()

# %%
# Example: Patch a white rectangle at (y0, x0) with height h and width w

# If rgbmap is float [0,1], use 1.0; if uint8 [0,255], use 255
if rgbmap.dtype == np.uint8:
    white = 255
else:
    white = 1.0

y0, x0 = 7409, 6792    # Top-left corner of the rectangle (change as needed)
h, w = 5, 5       # Height and width of the rectangle (change as needed)
rgbmap[y0:y0+h, x0:x0+w, :] = white

y0, x0 = 3466, 6792    # Top-left corner of the rectangle (change as needed)
h, w = 5, 5       # Height and width of the rectangle (change as needed)
rgbmap[y0:y0+h, x0:x0+w, :] = white

y0, x0 = 7256, 3492    # Top-left corner of the rectangle (change as needed)
h, w = 5, 5       # Height and width of the rectangle (change as needed)
rgbmap[y0:y0+h, x0:x0+w, :] = white

y0, x0 = 3406, 4689    # Top-left corner of the rectangle (change as needed)
h, w = 5, 5       # Height and width of the rectangle (change as needed)
rgbmap[y0:y0+h, x0:x0+w, :] = white

plt.imshow(rgbmap)
plt.title("Patched Map")
plt.show()

# %%
intersections = [
    (8642, 1564),
    (8654, 6755),
    (7250, 1552),
    (7241, 2446),
    (7242, 3652),
    (7242, 4704),
    (7257, 6773),
    (6199, 1552),
    (6197, 2439),
    (3349, 1545),
    (3350, 2456),
    (3350, 3639),
    (3335, 4714),
    (3315, 6773),
    (2456, 1563),
    (2446, 6757),
 ]

intersections = [(y, x) for x, y in intersections]

# %%
map_edges = {}
for i, coord in enumerate(intersections):
    x, y = coord
    map_edges[i] = (x, y)
    print(i, map_edges[i])
# Out:
# 0 (1564, 8642)
# 1 (6755, 8654)
# 2 (1552, 7250)
# 3 (2446, 7241)
# 4 (3652, 7242)
# 5 (4704, 7242)
# 6 (6773, 7257)
# 7 (1552, 6199)
# 8 (2439, 6197)
# 9 (1545, 3349)
# 10 (2456, 3350)
# 11 (3639, 3350)
# 12 (4714, 3335)
# 13 (6773, 3315)
# 14 (1563, 2456)
# 15 (6757, 2446)

# %%
from skimage.color import rgb2gray
from skimage.morphology import skeletonize

def get_midlane_coords(rgbmap):
    gray = rgb2gray(rgbmap)
    binary = gray > 0.99  # Adjust threshold if needed
    # Skeletonize to get lane centerlines
    skeleton = skeletonize(binary)
    # Get coordinates of skeleton pixels (centerline points)
    centerline_coords = np.argwhere(skeleton)
    return centerline_coords

def sample_equidistant_points(path_coords, step=100):
    """Given a list of (y, x) coords, return equidistant points along the path."""
    path_coords = np.array(path_coords)
    # Compute cumulative distance along the path
    deltas = np.diff(path_coords, axis=0)
    dists = np.sqrt((deltas**2).sum(axis=1))
    cumdist = np.insert(np.cumsum(dists), 0, 0)
    total_dist = cumdist[-1]
    n_points = int(total_dist // step)
    if n_points < 2:
        return path_coords  # Path too short, return as is
    sample_dists = np.linspace(0, total_dist, n_points)
    sampled_points = np.empty((n_points, 2))
    sampled_points[0] = path_coords[0]
    sampled_points[-1] = path_coords[-1]
    j = 1
    for i in range(1, n_points-1):
        d = sample_dists[i]
        while cumdist[j] < d:
            j += 1
        ratio = (d - cumdist[j-1]) / (cumdist[j] - cumdist[j-1])
        sampled_points[i] = path_coords[j-1] + ratio * (path_coords[j] - path_coords[j-1])
    return sampled_points.astype(int)

def get_route_waypoints(pixel_graph, node_a, node_b ):
    # 2. For each consecutive pair, find pixel path and discretize
    pixel_path = nx.shortest_path(pixel_graph, node_a, node_b)
    waypoints = sample_equidistant_points(pixel_path, step=300)  # step in pixels
    return waypoints

def compute_lane_offsets(waypoints, lane_width=6.0):
    """
    Given centerline waypoints (N,2), return left and right lane waypoints.
    lane_width: total width of both lanes (in pixels, adjust as needed)
    """
    waypoints = np.array(waypoints)
    left_lane = []
    right_lane = []
    side_1, side_2 = [], []
    offset = lane_width / 2.0
    offset_ped = lane_width + 10

    for i in range(len(waypoints)):
        # Compute direction vector
        if i == 0:
            direction = waypoints[i+1] - waypoints[i]
        elif i == len(waypoints) - 1:
            direction = waypoints[i] - waypoints[i-1]
        else:
            direction = waypoints[i+1] - waypoints[i-1]
        direction = direction / np.linalg.norm(direction)
        # Normal vector (perpendicular, 2D)
        normal = np.array([-direction[1], direction[0]])
        # Offset points
        left_lane.append(waypoints[i] + offset * normal)
        right_lane.append(waypoints[i] - offset * normal)
        side_1.append(waypoints[i] + offset_ped * normal)
        side_2.append(waypoints[i] - offset_ped * normal)
    return np.array(left_lane), np.array(right_lane), np.array(side_1), np.array(side_2)

# %%
def show_route(rgbmap, waypoints):
    # 3. Visualize the full route
    plt.imshow(rgbmap)
    for idx, p in enumerate(intersections):
        plt.scatter(p[1], p[0], c='red', s=80, zorder=3)
        plt.annotate(str(idx), (p[1], p[0]), color='k', fontsize=12, weight='bold', zorder=4)
    plt.plot(waypoints[:,1], waypoints[:,0], 'orange', lw=2, zorder=5, label='Discretized Route')
    plt.scatter(waypoints[:,1], waypoints[:,0], c='b', s=1, zorder=6, label='Waypoints')
    plt.axis('off')
    plt.legend()
    plt.show()

# %%
centerline_coords = get_midlane_coords(rgbmap)
centerline_coords = centerline_coords[:, [1, 0]]

# %%
# 1. Find the closest centerline point for each intersection
intersection_nodes = []
for intersection in intersections:
    dists = np.linalg.norm(centerline_coords - intersection, axis=1)
    idx_min = np.argmin(dists)
    intersection_nodes.append(tuple(centerline_coords[idx_min]))

# %%
plt.imshow(rgbmap)
plt.scatter(centerline_coords[:,0], centerline_coords[:,1], c='gray', s=0.1, label='All Centerlines')
for idx, p in enumerate(intersections):
    plt.scatter(p[0], p[1], c='red', s=20)
    plt.annotate(str(idx), (p[0], p[1]), color='k', fontsize=10, weight='bold')
plt.legend()
plt.title("Closest Centerlines & Midpoints Between Intersections")
plt.show()

# %%
# 2. Build a pixel adjacency graph for centerline_coords (for pathfinding only)
pixel_graph = nx.Graph()
centerline_set = set(map(tuple, centerline_coords))
for y, x in centerline_coords:
    for dy in [-1, 0, 1]:
        for dx in [-1, 0, 1]:
            if dy == 0 and dx == 0:
                continue
            neighbor = (y + dy, x + dx)
            if neighbor in centerline_set:
                pixel_graph.add_edge((y, x), neighbor)

# 3. Precompute a set of "blocked" pixels for each intersection (within a radius)
block_radius = 50  # pixels
blocked_pixels = []
for node in intersection_nodes:
    y0, x0 = node
    pixels = set()
    for dy in range(-block_radius, block_radius+1):
        for dx in range(-block_radius, block_radius+1):
            if dy**2 + dx**2 <= block_radius**2:
                pixels.add((y0+dy, x0+dx))
    blocked_pixels.append(pixels)

# 4. Build the intersection graph
G_intersections = nx.Graph()
for idx in range(len(intersections)):
    G_intersections.add_node(idx, pos=intersections[idx])

for i, node_a in enumerate(intersection_nodes):
    for j, node_b in enumerate(intersection_nodes):
        if i < j:
            try:
                path = nx.shortest_path(pixel_graph, node_a, node_b)
                path_set = set(path[1:-1])
                blocked = False
                for k, block in enumerate(blocked_pixels):
                    if k != i and k != j and path_set & block:
                        blocked = True
                        break
                if not blocked:
                    G_intersections.add_edge(i, j)
            except nx.NetworkXNoPath:
                continue

print("Direct intersection pairs (by index):", list(G_intersections.edges))

# Visualization
plt.imshow(rgbmap)
for idx, p in enumerate(intersections):
    plt.scatter(p[0], p[1], c='red', s=20)
    plt.annotate(str(idx), (p[0], p[1]), color='k', fontsize=10, weight='bold')
for i, j in G_intersections.edges:
    a = intersections[i]
    b = intersections[j]
    plt.plot([a[0], b[0]], [a[1], b[1]], 'c-', lw=2)
plt.title("Intersection Graph (nodes=intersections, edges=direct paths)")
plt.show()
# Out:
# Direct intersection pairs (by index): [(0, 1), (0, 2), (1, 6), (2, 3), (2, 7), (3, 4), (3, 8), (4, 5), (4, 11), (5, 6), (5, 12), (6, 13), (7, 8), (7, 9), (8, 10), (9, 10), (9, 14), (10, 11), (11, 12), (12, 13), (13, 15), (14, 15)]

# %% [markdown]
# ## LEFT AND RIGHT LANES

# %%
len(list(G_intersections.edges))
# Out:
# 22

# %%
for (i, j) in list(G_intersections.edges):
    node_a = intersection_nodes[i]
    node_b = intersection_nodes[j]
    path = nx.shortest_path(pixel_graph, node_a, node_b)

# %%
import numpy as np
import networkx as nx

def offset_segment(path, offset):
    """
    Offset a polyline path to the left and right by 'offset' pixels.
    Returns two lists of (y, x) tuples — safe for use in NetworkX graphs.
    """
    path = np.array(path)
    y, x = path[:, 0], path[:, 1]

    # Compute tangent direction
    dy = np.gradient(y)
    dx = np.gradient(x)
    norm = np.hypot(dx, dy) + 1e-8  # avoid division by zero
    dx, dy = dx / norm, dy / norm

    # Compute perpendicular unit vectors
    perp_y = -dx
    perp_x = dy

    # Apply offset
    left_y = y + offset * perp_y
    left_x = x + offset * perp_x
    right_y = y - offset * perp_y
    right_x = x - offset * perp_x

    # Convert to integer tuples (y, x)
    left_path = [(int(round(yy)), int(round(xx))) for yy, xx in zip(left_y, left_x)]
    right_path = [(int(round(yy)), int(round(xx))) for yy, xx in zip(right_y, right_x)]

    return left_path, right_path

def shifted_intersection_point(seg_start, seg_end, offset_along=0.1):
    """
    Compute a point along the segment to attach lane endpoints for smooth intersections.
    
    offset_along: fraction of segment length to shift from intersection
    """
    y0, x0 = seg_start
    y1, x1 = seg_end
    y_shift = y0 + offset_along * (y1 - y0)
    x_shift = x0 + offset_along * (x1 - x0)
    return int(round(y_shift)), int(round(x_shift))

# %%
pixel_graph_left = nx.Graph()
pixel_graph_right = nx.Graph()
lane_offset = 30  # adjust for your map scale

segment_info = {}  # key: (node_a_idx, node_b_idx), value: dict with lane info

for (i, j) in G_intersections.edges:
    node_a = intersection_nodes[i]
    node_b = intersection_nodes[j]

    try:
        path = nx.shortest_path(pixel_graph, node_a, node_b)
        left_path, right_path = offset_segment(path, lane_offset)

        # Ensure valid tuples (no duplicates or out-of-bounds)
        left_path = [tuple(p) for p in left_path if len(p) == 2]
        right_path = [tuple(p) for p in right_path if len(p) == 2]

        # Example: left lane
        start_shifted = shifted_intersection_point(node_a, node_b, offset_along=0.15)
        end_shifted   = shifted_intersection_point(node_b, node_a, offset_along=0.15)

        # Replace the first and last node of the lane path
        left_path[0] = start_shifted
        left_path[-1] = end_shifted

        # Add to respective lane graphs
        nx.add_path(pixel_graph_left, left_path)
        nx.add_path(pixel_graph_right, right_path)

        # Store metadata
        segment_info[(i, j)] = {
            "left_path": left_path,
            "right_path": right_path,
            "direction": "i->j",  # default
            "lane": "right",      # default lane if needed
        }
    except nx.NetworkXNoPath:
        continue

# %%
wrong_segments = [(9, 10), (10, 11), (11, 12), (12, 13)]  # example
for seg in wrong_segments:
    # Flip direction
    segment_info[seg]["direction"] = "j->i"
    # Optionally swap left/right paths
    segment_info[seg]["left_path"], segment_info[seg]["right_path"] = \
        segment_info[seg]["right_path"], segment_info[seg]["left_path"]

pixel_graph_left.clear()
pixel_graph_right.clear()

for seg, info in segment_info.items():
    nx.add_path(pixel_graph_left, info["left_path"])
    nx.add_path(pixel_graph_right, info["right_path"])

# %%
plt.imshow(rgbmap)
plt.scatter(*zip(*intersection_nodes), c='red', s=20, label='Intersections')
y, x = zip(*pixel_graph_left.nodes)
plt.scatter(y, x, s=0.5, c='lime', label='Left Lane')
y, x = zip(*pixel_graph_right.nodes)
plt.scatter(y, x, s=0.5, c='cyan', label='Right Lane')
plt.legend()

for idx, p in enumerate(intersections):
    plt.scatter(p[0], p[1], c='red', s=20)
    plt.annotate(str(idx), (p[0], p[1]), color='k', fontsize=10, weight='bold')

plt.show()

# %%
# Deepcopy to avoid modifying the original
map_data = deepcopy(segment_info)

# Initialize left and right lane graphs
G_left = nx.DiGraph()
G_right = nx.DiGraph()

# --- Helper function to add a lane segment to a graph ---
def add_lane_segment(G, seg_id, lane_points, intersections, lane_type, step_cost=1.0, conn_cost=0.3):
    """
    Adds sampled waypoints and connects them to intersections.
    """
    a, b = seg_id
    edge_label = f"{a}_{b}_{lane_type}"
    n_pts = len(lane_points)
    if n_pts < 2:
        return G  # skip short or invalid segments

    # Add waypoints along the lane
    for i, pt in enumerate(lane_points):
        node_id = f"{edge_label}_{i}"
        G.add_node(node_id, pos=pt, lane=lane_type, segment=(a, b))

        # Connect consecutive points
        if i > 0:
            prev_id = f"{edge_label}_{i-1}"
            G.add_edge(prev_id, node_id, cost=step_cost)

    # Connect start and end to intersections (slightly shifted)
    start_node = f"{edge_label}_0"
    end_node = f"{edge_label}_{n_pts-1}"

    start_inter = f"intersection_{a}"
    end_inter = f"intersection_{b}"

    if start_inter not in G:
        G.add_node(start_inter, pos=intersections[a], lane="intersection")
    if end_inter not in G:
        G.add_node(end_inter, pos=intersections[b], lane="intersection")

    # Instead of connecting both directions:
    G.add_edge(start_inter, start_node, cost=conn_cost)
    # Avoid the redundant reverse connection if graph is directed


    return G

# --- Build the graphs ---
for seg_id, seg_data in map_data.items():
    if seg_data["direction"] == "i->j":
        a, b = seg_id
    else:
        b, a = seg_id
    for lane_type in ["left_path", "right_path"]:
        waypoints = sample_equidistant_points(seg_data[lane_type], step=100)

        # Snap endpoints to intersection coordinates
        waypoints[0] = intersections[a]
        waypoints[-1] = intersections[b]

        map_data[seg_id][lane_type] = waypoints

        if lane_type == "left_path":
            G_left = add_lane_segment(G_left, seg_id, waypoints, intersections, "L")
        else:
            G_right = add_lane_segment(G_right, seg_id, waypoints, intersections, "R")


# --- Optionally combine both lane graphs into one ---
G_combined = nx.compose(G_left, G_right)

# %%
pos = nx.get_node_attributes(G_right, "pos")
nx.draw(G_right, pos, node_size=5, with_labels=False)

# %%
map_data = deepcopy(segment_info)

for segment in map_data.keys():
    
    for lane in ["left_path", "right_path"]:
        waypoints = sample_equidistant_points(map_data[segment][lane], step=100)
        map_data[segment][lane] = waypoints

# %%
def connect_graph(lane="left"):
    segment_info = {}  # key: (node_a_idx, node_b_idx), value: dict with lane info
    G = nx.DiGraph()

    for i, j in list(G_intersections.edges):
        
        node_a = intersection_nodes[i]
        node_b = intersection_nodes[j]

        path = nx.shortest_path(pixel_graph, node_a, node_b)
        left_path, right_path = offset_segment(path, lane_offset)

        # Ensure valid tuples (no duplicates or out-of-bounds)
        left_path = [tuple(p) for p in left_path if len(p) == 2]
        right_path = [tuple(p) for p in right_path if len(p) == 2]

        # Sample equidistant points (e.g., every n pixels)
        waypoints_left = sample_equidistant_points(left_path, step=100)
        waypoints_right = sample_equidistant_points(right_path, step=100)

        # Store metadata
        segment_info[(i, j)] = {
            "left_path": left_path,
            "right_path": right_path,
            "direction": "i->j",  # default
            "lane": lane,      # default lane if needed
        }

# %%
import networkx as nx
import copy

pixel_graph_left_orig = copy.deepcopy(pixel_graph_left)
pixel_graph_right_orig = copy.deepcopy(pixel_graph_right)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,10))
plt.imshow(rgbmap, alpha=0.5)
y, x = zip(*pixel_graph_left.nodes)
plt.scatter(y, x, s=1, c='lime', label='Left Lane')
y, x = zip(*pixel_graph_right.nodes)
plt.scatter(y, x, s=1, c='cyan', label='Right Lane')

plt.scatter(*zip(*intersection_nodes), c='red', s=20, label='Intersections')
plt.legend()
plt.show()

# %%
# Store metadata
segment_info[(i, j)] = {
    "left_path": left_path,
    "right_path": right_path,
    "direction": "i->j",  # default
    "lane": "right",      # default lane if needed
}

edge_waypoints = {}
edge_lanes_r = {}
edge_lanes_l = {}


    edge_lanes_r[(i, j)] = right_lane 
    edge_lanes_l[(i, j)] = left_lane

# %%
def add_center_waypoints(G, edge_id, centerline, cost_forward=1.0, lane="C", cost_to_intersection=0.1):
    """
    Adds centerline waypoints and connects them to intersection nodes.
    
    Parameters:
        G : networkx.Graph
            The planning graph to modify.
        edge_id : tuple
            A pair of intersection indices (i, j).
        centerline : list of (x, y)
            Waypoints along the road between i and j.
        cost_forward : float
            Cost of traveling forward along the centerline.
        cost_to_intersection : float
            Cost of entering or exiting an intersection.
    """
    edge_label = f"{edge_id[0]}-{edge_id[1]}"
    N = len(centerline)

    for i in range(N):
        c_node = f"{edge_label}_{lane}_{i}"
        G.add_node(c_node, pos=centerline[i], lane=lane)

        if i < N - 1:
            next_node = f"{edge_label}_{lane}_{i+1}"
            G.add_edge(c_node, next_node, cost=cost_forward)

    # --- Connect endpoints to intersections ---
    start_node = f"{edge_label}_{lane}_0"
    end_node = f"{edge_label}_{lane}_{N-1}"

    start_intersection = f"intersection_{edge_id[0]}"
    end_intersection = f"intersection_{edge_id[1]}"

    G.add_node(start_intersection, pos=centerline[0], lane="intersection")
    G.add_node(end_intersection, pos=centerline[-1], lane="intersection")

    G.add_edge(start_intersection, start_node, cost=cost_to_intersection)
    G.add_edge(start_node, start_intersection, cost=cost_to_intersection)

    G.add_edge(end_intersection, end_node, cost=cost_to_intersection)
    G.add_edge(end_node, end_intersection, cost=cost_to_intersection)

    return G

def create_lane_graph(G, edge_id, edge_waypoints, waypoints, lane="center"):
    i,j = edge_id
    G = add_center_waypoints(G, edge_id=edge_id, centerline=waypoints, lane=lane)

    # After building each segment of waypoints for an edge (i, j):
    last_c = f"{i}-{j}_{lane}_{len(waypoints)-1}"

    # For all other edges connected to 'j'
    for neighbor in G_intersections.neighbors(j):
        if neighbor == i:
            continue
        neighbor_edge = (j, neighbor)
        neighbor_waypoints = edge_waypoints.get(neighbor_edge) or edge_waypoints.get((neighbor, j))
        if neighbor_waypoints is None:
            continue
        first_neighbor_c = f"{j}-{neighbor}_{lane}_0"
        G.add_edge(last_c, first_neighbor_c, cost=1.0)  # You can tune the cost

    return G


import networkx as nx
import matplotlib.pyplot as plt

# --- Parameters ---
lane_width_pixels = 80  # Adjust to your map's scale
sample_step = 100       # Step size for waypoint sampling
add_lanes = False

# --- Containers ---
edge_waypoints = {}
edge_lanes_r = {}
edge_lanes_l = {}
edge_ped_r = {}
edge_ped_l = {}

# --- Full planning graph ---
G_center = G_intersections.copy()
G_left = G_intersections.copy()
G_right = G_intersections.copy()
G_ped = G_intersections.copy()

# --- Main loop ---
for i, j in list(G_intersections.edges):
    node_a = intersection_nodes[i]
    node_b = intersection_nodes[j]
     # Get path in pixel_graph and sample waypoints
    path = nx.shortest_path(pixel_graph, node_a, node_b)
    waypoints = sample_equidistant_points(path, step=sample_step)

    # Compute lane offsets
    left_lane, right_lane, side_1, side_2 = compute_lane_offsets(waypoints, lane_width=lane_width_pixels)

    # Save for visualization/debugging
    edge_waypoints[(i, j)] = waypoints
    edge_lanes_l[(i, j)] = left_lane
    edge_lanes_r[(i, j)] = right_lane
    edge_ped_l[(i, j)] = side_1
    edge_ped_r[(i, j)] = side_2
            

    G_center = create_lane_graph(G_center, edge_id=(i,j),
     edge_waypoints=edge_waypoints, waypoints=waypoints, lane="C")

    G_left= create_lane_graph(G_left, edge_id=(i,j),
     edge_waypoints=edge_lanes_l, waypoints=left_lane, lane="L")

    G_right= create_lane_graph(G_right, edge_id=(i,j),
     edge_waypoints=edge_lanes_r, waypoints=right_lane, lane="R")
     
    graph_waypoints = {
        "C": waypoints,
        "L": side_1,
        "R": side_2,
    }
     
    G_ped = add_waypoints_with_lanes(G_ped, edge_id=(i,j), waypoints=graph_waypoints)

# %% [markdown]
# ## V0

# %%
options = {
    "font_size": 18,
    "node_size": 1000,
    "node_color": "white",
    "edgecolors": "black",
    "linewidths": 5,
    "width": 5,
}
nx.draw_networkx(G_intersections, map_edges, **options)

# Set margins for the axes so that nodes aren't clipped
ax = plt.gca()
ax.margins(0.20)
plt.axis("off")
plt.show()

# %%
# Usage
lane_width_pixels = 80  # Adjust to your map's scale

# Example: Discretize all edges in G_intersections
edge_waypoints = {}
edge_lanes_r = {}
edge_lanes_l = {}
edge_ped_l = {}
edge_ped_r = {}
for i, j in G_intersections.edges:
    node_a = intersection_nodes[i]
    node_b = intersection_nodes[j]
    # Get the pixel path between intersections
    path = nx.shortest_path(pixel_graph, node_a, node_b)
    # Sample equidistant points (e.g., every n pixels)
    waypoints = sample_equidistant_points(path, step=100)

    left_lane, right_lane, side1, side2 = compute_lane_offsets(waypoints, lane_width=lane_width_pixels)
    edge_waypoints[(i, j)] = waypoints
    edge_lanes_r[(i, j)] = right_lane 
    edge_lanes_l[(i, j)] = left_lane 
    edge_ped_l[(i, j)] = side1 
    edge_ped_r[(i, j)] = side2

# %%
# Visualize one edge's waypoints
plt.imshow(rgbmap)
for idx, p in enumerate(intersections):
    plt.scatter(p[0], p[1], c='red', s=50)

for (i, j), waypoints in edge_waypoints.items():
    plt.plot(waypoints[:,0], waypoints[:,1], 'k.', markersize=3)

for (i, j), waypoints in edge_ped_r.items():
    plt.plot(waypoints[:,0], waypoints[:,1], 'g.', markersize=2)

for (i, j), waypoints in edge_ped_l.items():
    plt.plot(waypoints[:,0], waypoints[:,1], 'b.', markersize=2)

# %%
def get_closest_node(graph, point):
    # Assume graph nodes are (x, y) tuples
    return min(graph.nodes, key=lambda n: (n[0] - point[0])**2 + (n[1] - point[1])**2)

# %% [markdown]
# # GENERATE GRAPH!!!

# %%
def add_center_waypoints(G, edge_id, centerline, cost_forward=1.0, lane="C", cost_to_intersection=0.1):
    """
    Adds centerline waypoints and connects them to intersection nodes.
    
    Parameters:
        G : networkx.Graph
            The planning graph to modify.
        edge_id : tuple
            A pair of intersection indices (i, j).
        centerline : list of (x, y)
            Waypoints along the road between i and j.
        cost_forward : float
            Cost of traveling forward along the centerline.
        cost_to_intersection : float
            Cost of entering or exiting an intersection.
    """
    edge_label = f"{edge_id[0]}-{edge_id[1]}"
    N = len(centerline)

    for i in range(N):
        c_node = f"{edge_label}_{lane}_{i}"
        G.add_node(c_node, pos=centerline[i], lane=lane)

        if i < N - 1:
            next_node = f"{edge_label}_{lane}_{i+1}"
            G.add_edge(c_node, next_node, cost=cost_forward)

    # --- Connect endpoints to intersections ---
    start_node = f"{edge_label}_{lane}_0"
    end_node = f"{edge_label}_{lane}_{N-1}"

    start_intersection = f"intersection_{edge_id[0]}"
    end_intersection = f"intersection_{edge_id[1]}"

    G.add_node(start_intersection, pos=centerline[0], lane="intersection")
    G.add_node(end_intersection, pos=centerline[-1], lane="intersection")

    G.add_edge(start_intersection, start_node, cost=cost_to_intersection)
    G.add_edge(start_node, start_intersection, cost=cost_to_intersection)

    G.add_edge(end_intersection, end_node, cost=cost_to_intersection)
    G.add_edge(end_node, end_intersection, cost=cost_to_intersection)

    return G

# %%
def add_waypoints_with_lanes(
    G, edge_id, waypoints, cost_forward=1.0, cost_to_intersection=0.1, cost_cross=5.0
):
    """
    Adds centerline + lane waypoints to the planning graph and connects them.

    Parameters:
        G : networkx.Graph
            The planning graph to modify.
        edge_id : tuple
            A pair of intersection indices (i, j).
        waypoints : dict
            Dictionary of lane polylines with keys "C", "L", "R".
            Each is a list of (x,y) coordinates of same length.
        cost_forward : float
            Cost of traveling forward along a lane.
        cost_to_intersection : float
            Cost of entering/exiting an intersection.
        cost_cross : float
            Cost of crossing horizontally (lane change).
    """
    edge_label = f"{edge_id[0]}-{edge_id[1]}"
    N = len(waypoints["C"])  # assume all lanes same length

    # --- Add nodes and vertical edges (forward along each lane) ---
    for i in range(N):
        for lane, coords in waypoints.items():
            node = f"{edge_label}_{lane}_{i}"
            try:
                pos = coords[i]
            except Exception as e:
                print(node)
                continue
            
            G.add_node(node, pos=tuple(pos), lane=lane)

            # vertical forward edge
            if i < N - 1:
                next_node = f"{edge_label}_{lane}_{i+1}"
                G.add_edge(node, next_node, cost=cost_forward)

        # --- Add horizontal cross edges at this index ---
        if all(lane in waypoints for lane in ["L", "C", "R"]):
            nL = f"{edge_label}_L_{i}"
            nC = f"{edge_label}_C_{i}"
            nR = f"{edge_label}_R_{i}"
            # L <-> C
            G.add_edge(nL, nC, cost=cost_cross)
            G.add_edge(nC, nL, cost=cost_cross)
            # C <-> R
            G.add_edge(nC, nR, cost=cost_cross)
            G.add_edge(nR, nC, cost=cost_cross)

    # --- Connect endpoints of all lanes to intersections ---
    start_intersection = f"intersection_{edge_id[0]}"
    end_intersection = f"intersection_{edge_id[1]}"

    G.add_node(start_intersection, pos=waypoints["C"][0], lane="intersection")
    G.add_node(end_intersection, pos=waypoints["C"][-1], lane="intersection")

    for lane in waypoints.keys():
        start_node = f"{edge_label}_{lane}_0"
        end_node = f"{edge_label}_{lane}_{N-1}"

        # connect start intersection
        G.add_edge(start_intersection, start_node, cost=cost_to_intersection)
        G.add_edge(start_node, start_intersection, cost=cost_to_intersection)

        # connect end intersection
        G.add_edge(end_intersection, end_node, cost=cost_to_intersection)
        G.add_edge(end_node, end_intersection, cost=cost_to_intersection)

    return G

# %%
def create_lane_graph(G, edge_id, edge_waypoints, waypoints, lane="center"):
    i,j = edge_id
    G = add_center_waypoints(G, edge_id=edge_id, centerline=waypoints, lane=lane)

    # After building each segment of waypoints for an edge (i, j):
    last_c = f"{i}-{j}_{lane}_{len(waypoints)-1}"

    # For all other edges connected to 'j'
    for neighbor in G_intersections.neighbors(j):
        if neighbor == i:
            continue
        neighbor_edge = (j, neighbor)
        neighbor_waypoints = edge_waypoints.get(neighbor_edge) or edge_waypoints.get((neighbor, j))
        if neighbor_waypoints is None:
            continue
        first_neighbor_c = f"{j}-{neighbor}_{lane}_0"
        G.add_edge(last_c, first_neighbor_c, cost=1.0)  # You can tune the cost

    return G


import networkx as nx
import matplotlib.pyplot as plt

# --- Parameters ---
lane_width_pixels = 80  # Adjust to your map's scale
sample_step = 100       # Step size for waypoint sampling
add_lanes = False

# --- Containers ---
edge_waypoints = {}
edge_lanes_r = {}
edge_lanes_l = {}
edge_ped_r = {}
edge_ped_l = {}

# --- Full planning graph ---
G_center = G_intersections.copy()
G_left = G_intersections.copy()
G_right = G_intersections.copy()
G_ped = G_intersections.copy()

# --- Main loop ---
for i, j in G_intersections.edges:
    node_a = intersection_nodes[i]
    node_b = intersection_nodes[j]
     # Get path in pixel_graph and sample waypoints
    path = nx.shortest_path(pixel_graph, node_a, node_b)
    waypoints = sample_equidistant_points(path, step=sample_step)

    # Compute lane offsets
    left_lane, right_lane, side_1, side_2 = compute_lane_offsets(waypoints, lane_width=lane_width_pixels)

    # Save for visualization/debugging
    edge_waypoints[(i, j)] = waypoints
    edge_lanes_l[(i, j)] = left_lane
    edge_lanes_r[(i, j)] = right_lane
    edge_ped_l[(i, j)] = side_1
    edge_ped_r[(i, j)] = side_2
            

    G_center = create_lane_graph(G_center, edge_id=(i,j),
     edge_waypoints=edge_waypoints, waypoints=waypoints, lane="C")

    G_left= create_lane_graph(G_left, edge_id=(i,j),
     edge_waypoints=edge_lanes_l, waypoints=left_lane, lane="L")

    G_right= create_lane_graph(G_right, edge_id=(i,j),
     edge_waypoints=edge_lanes_r, waypoints=right_lane, lane="R")
     
    graph_waypoints = {
        "C": waypoints,
        "L": side_1,
        "R": side_2,
    }
     
    G_ped = add_waypoints_with_lanes(G_ped, edge_id=(i,j), waypoints=graph_waypoints)

# %%
merge_threshold = 10
# --- Merge redundant nodes ---
pos = nx.get_node_attributes(G_planning, 'pos')
positions = list(pos.items())

for i in range(len(positions)):
    node_i, pos_i = positions[i]
    for j in range(i+1, len(positions)):
        node_j, pos_j = positions[j]
        if np.linalg.norm(np.array(pos_i) - np.array(pos_j)) < merge_threshold:
            # Merge node_j into node_i
            if node_j in G_planning and node_i in G_planning:
                nx.relabel_nodes(G_planning, {node_j: node_i}, copy=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 3
#       1 merge_threshold = 10
#       2 # --- Merge redundant nodes ---
# ----> 3 pos = nx.get_node_attributes(G_planning, 'pos')
#       4 positions = list(pos.items())
#       6 for i in range(len(positions)):
#
# NameError: name 'G_planning' is not defined

# %%
for node_id in G_center.nodes:
    print(G_center.nodes[node_id])
# Out:
# {'pos': (1564, 8642)}
# {'pos': (6755, 8654)}
# {'pos': (1552, 7250)}
# {'pos': (2446, 7241)}
# {'pos': (3652, 7242)}
# {'pos': (4704, 7242)}
# {'pos': (6773, 7257)}
# {'pos': (1552, 6199)}
# {'pos': (2439, 6197)}
# {'pos': (1545, 3349)}
# {'pos': (2456, 3350)}
# {'pos': (3639, 3350)}
# {'pos': (4714, 3335)}
# {'pos': (6773, 3315)}
# {'pos': (1563, 2456)}
# {'pos': (6757, 2446)}
# {'pos': array([1564, 8642]), 'lane': 'C'}
# {'pos': array([1643, 8694]), 'lane': 'C'}
# {'pos': array([1742, 8703]), 'lane': 'C'}
# {'pos': array([1845, 8703]), 'lane': 'C'}
# {'pos': array([1947, 8703]), 'lane': 'C'}
# {'pos': array([2050, 8703]), 'lane': 'C'}
# {'pos': array([2153, 8703]), 'lane': 'C'}
# {'pos': array([2256, 8703]), 'lane': 'C'}
# {'pos': array([2358, 8703]), 'lane': 'C'}
# {'pos': array([2461, 8704]), 'lane': 'C'}
# {'pos': array([2564, 8704]), 'lane': 'C'}
# {'pos': array([2666, 8703]), 'lane': 'C'}
# {'pos': array([2769, 8703]), 'lane': 'C'}
# {'pos': array([2871, 8703]), 'lane': 'C'}
# {'pos': array([2974, 8703]), 'lane': 'C'}
# {'pos': array([3077, 8703]), 'lane': 'C'}
# {'pos': array([3180, 8703]), 'lane': 'C'}
# {'pos': array([3282, 8703]), 'lane': 'C'}
# {'pos': array([3385, 8703]), 'lane': 'C'}
# {'pos': array([3488, 8703]), 'lane': 'C'}
# {'pos': array([3591, 8703]), 'lane': 'C'}
# {'pos': array([3693, 8703]), 'lane': 'C'}
# {'pos': array([3796, 8703]), 'lane': 'C'}
# {'pos': array([3899, 8703]), 'lane': 'C'}
# {'pos': array([4002, 8703]), 'lane': 'C'}
# {'pos': array([4104, 8703]), 'lane': 'C'}
# {'pos': array([4207, 8703]), 'lane': 'C'}
# {'pos': array([4310, 8703]), 'lane': 'C'}
# {'pos': array([4413, 8703]), 'lane': 'C'}
# {'pos': array([4515, 8703]), 'lane': 'C'}
# {'pos': array([4618, 8703]), 'lane': 'C'}
# {'pos': array([4721, 8703]), 'lane': 'C'}
# {'pos': array([4824, 8703]), 'lane': 'C'}
# {'pos': array([4926, 8703]), 'lane': 'C'}
# {'pos': array([5029, 8703]), 'lane': 'C'}
# {'pos': array([5132, 8703]), 'lane': 'C'}
# {'pos': array([5235, 8703]), 'lane': 'C'}
# {'pos': array([5337, 8703]), 'lane': 'C'}
# {'pos': array([5440, 8703]), 'lane': 'C'}
# {'pos': array([5543, 8703]), 'lane': 'C'}
# {'pos': array([5646, 8703]), 'lane': 'C'}
# {'pos': array([5748, 8703]), 'lane': 'C'}
# {'pos': array([5851, 8703]), 'lane': 'C'}
# {'pos': array([5954, 8703]), 'lane': 'C'}
# {'pos': array([6057, 8703]), 'lane': 'C'}
# {'pos': array([6159, 8703]), 'lane': 'C'}
# {'pos': array([6262, 8703]), 'lane': 'C'}
# {'pos': array([6365, 8703]), 'lane': 'C'}
# {'pos': array([6468, 8703]), 'lane': 'C'}
# {'pos': array([6570, 8703]), 'lane': 'C'}
# {'pos': array([6671, 8696]), 'lane': 'C'}
# {'pos': array([6755, 8654]), 'lane': 'C'}
# {'pos': array([1564, 8642]), 'lane': 'intersection'}
# {'pos': array([6755, 8654]), 'lane': 'intersection'}
# {'pos': array([1564, 8642]), 'lane': 'C'}
# {'pos': array([1537, 8544]), 'lane': 'C'}
# {'pos': array([1535, 8436]), 'lane': 'C'}
# {'pos': array([1535, 8327]), 'lane': 'C'}
# {'pos': array([1535, 8218]), 'lane': 'C'}
# {'pos': array([1535, 8110]), 'lane': 'C'}
# {'pos': array([1535, 8001]), 'lane': 'C'}
# {'pos': array([1535, 7892]), 'lane': 'C'}
# {'pos': array([1535, 7783]), 'lane': 'C'}
# {'pos': array([1535, 7674]), 'lane': 'C'}
# {'pos': array([1535, 7566]), 'lane': 'C'}
# {'pos': array([1535, 7457]), 'lane': 'C'}
# {'pos': array([1536, 7348]), 'lane': 'C'}
# {'pos': array([1552, 7250]), 'lane': 'C'}
# {'pos': array([1552, 7250]), 'lane': 'intersection'}
# {'pos': array([6755, 8654]), 'lane': 'C'}
# {'pos': array([6789, 8558]), 'lane': 'C'}
# {'pos': array([6792, 8450]), 'lane': 'C'}
# {'pos': array([6793, 8341]), 'lane': 'C'}
# {'pos': array([6793, 8232]), 'lane': 'C'}
# {'pos': array([6793, 8122]), 'lane': 'C'}
# {'pos': array([6793, 8013]), 'lane': 'C'}
# {'pos': array([6793, 7904]), 'lane': 'C'}
# {'pos': array([6793, 7794]), 'lane': 'C'}
# {'pos': array([6793, 7686]), 'lane': 'C'}
# {'pos': array([6793, 7576]), 'lane': 'C'}
# {'pos': array([6793, 7467]), 'lane': 'C'}
# {'pos': array([6793, 7358]), 'lane': 'C'}
# {'pos': array([6773, 7257]), 'lane': 'C'}
# {'pos': array([6773, 7257]), 'lane': 'intersection'}
# {'pos': array([1552, 7250]), 'lane': 'C'}
# {'pos': array([1658, 7258]), 'lane': 'C'}
# {'pos': array([1772, 7258]), 'lane': 'C'}
# {'pos': array([1885, 7258]), 'lane': 'C'}
# {'pos': array([1999, 7258]), 'lane': 'C'}
# {'pos': array([2112, 7257]), 'lane': 'C'}
# {'pos': array([2225, 7257]), 'lane': 'C'}
# {'pos': array([2338, 7256]), 'lane': 'C'}
# {'pos': array([2446, 7241]), 'lane': 'C'}
# {'pos': array([2446, 7241]), 'lane': 'intersection'}
# {'pos': array([1552, 7250]), 'lane': 'C'}
# {'pos': array([1535, 7138]), 'lane': 'C'}
# {'pos': array([1535, 7019]), 'lane': 'C'}
# {'pos': array([1535, 6900]), 'lane': 'C'}
# {'pos': array([1535, 6782]), 'lane': 'C'}
# {'pos': array([1535, 6663]), 'lane': 'C'}
# {'pos': array([1535, 6544]), 'lane': 'C'}
# {'pos': array([1535, 6426]), 'lane': 'C'}
# {'pos': array([1535, 6307]), 'lane': 'C'}
# {'pos': array([1552, 6199]), 'lane': 'C'}
# {'pos': array([1552, 6199]), 'lane': 'intersection'}
# {'pos': array([2446, 7241]), 'lane': 'C'}
# {'pos': array([2549, 7250]), 'lane': 'C'}
# {'pos': array([2632, 7217]), 'lane': 'C'}
# {'pos': array([2732, 7257]), 'lane': 'C'}
# {'pos': array([2849, 7257]), 'lane': 'C'}
# {'pos': array([2965, 7257]), 'lane': 'C'}
# {'pos': array([3081, 7257]), 'lane': 'C'}
# {'pos': array([3197, 7257]), 'lane': 'C'}
# {'pos': array([3314, 7257]), 'lane': 'C'}
# {'pos': array([3430, 7257]), 'lane': 'C'}
# {'pos': array([3546, 7256]), 'lane': 'C'}
# {'pos': array([3652, 7242]), 'lane': 'C'}
# {'pos': array([3652, 7242]), 'lane': 'intersection'}
# {'pos': array([2446, 7241]), 'lane': 'C'}
# {'pos': array([2455, 7130]), 'lane': 'C'}
# {'pos': array([2455, 7012]), 'lane': 'C'}
# {'pos': array([2455, 6894]), 'lane': 'C'}
# {'pos': array([2455, 6776]), 'lane': 'C'}
# {'pos': array([2455, 6658]), 'lane': 'C'}
# {'pos': array([2455, 6540]), 'lane': 'C'}
# {'pos': array([2455, 6422]), 'lane': 'C'}
# {'pos': array([2455, 6304]), 'lane': 'C'}
# {'pos': array([2439, 6197]), 'lane': 'C'}
# {'pos': array([2439, 6197]), 'lane': 'intersection'}
# {'pos': array([3652, 7242]), 'lane': 'C'}
# {'pos': array([3764, 7257]), 'lane': 'C'}
# {'pos': array([3883, 7257]), 'lane': 'C'}
# {'pos': array([4002, 7257]), 'lane': 'C'}
# {'pos': array([4121, 7257]), 'lane': 'C'}
# {'pos': array([4239, 7257]), 'lane': 'C'}
# {'pos': array([4358, 7257]), 'lane': 'C'}
# {'pos': array([4477, 7257]), 'lane': 'C'}
# {'pos': array([4595, 7256]), 'lane': 'C'}
# {'pos': array([4704, 7242]), 'lane': 'C'}
# {'pos': array([4704, 7242]), 'lane': 'intersection'}
# {'pos': array([3652, 7242]), 'lane': 'C'}
# {'pos': array([3639, 7152]), 'lane': 'C'}
# {'pos': array([3638, 7049]), 'lane': 'C'}
# {'pos': array([3638, 6947]), 'lane': 'C'}
# {'pos': array([3638, 6844]), 'lane': 'C'}
# {'pos': array([3638, 6741]), 'lane': 'C'}
# {'pos': array([3638, 6638]), 'lane': 'C'}
# {'pos': array([3638, 6535]), 'lane': 'C'}
# {'pos': array([3638, 6432]), 'lane': 'C'}
# {'pos': array([3638, 6329]), 'lane': 'C'}
# {'pos': array([3638, 6226]), 'lane': 'C'}
# {'pos': array([3638, 6123]), 'lane': 'C'}
# {'pos': array([3638, 6020]), 'lane': 'C'}
# {'pos': array([3638, 5918]), 'lane': 'C'}
# {'pos': array([3638, 5815]), 'lane': 'C'}
# {'pos': array([3638, 5712]), 'lane': 'C'}
# {'pos': array([3638, 5609]), 'lane': 'C'}
# {'pos': array([3638, 5506]), 'lane': 'C'}
# {'pos': array([3638, 5403]), 'lane': 'C'}
# {'pos': array([3638, 5300]), 'lane': 'C'}
# {'pos': array([3638, 5197]), 'lane': 'C'}
# {'pos': array([3638, 5094]), 'lane': 'C'}
# {'pos': array([3638, 4991]), 'lane': 'C'}
# {'pos': array([3638, 4889]), 'lane': 'C'}
# {'pos': array([3638, 4786]), 'lane': 'C'}
# {'pos': array([3638, 4683]), 'lane': 'C'}
# {'pos': array([3638, 4580]), 'lane': 'C'}
# {'pos': array([3638, 4477]), 'lane': 'C'}
# {'pos': array([3638, 4374]), 'lane': 'C'}
# {'pos': array([3638, 4271]), 'lane': 'C'}
# {'pos': array([3638, 4168]), 'lane': 'C'}
# {'pos': array([3638, 4065]), 'lane': 'C'}
# {'pos': array([3638, 3962]), 'lane': 'C'}
# {'pos': array([3638, 3859]), 'lane': 'C'}
# {'pos': array([3638, 3757]), 'lane': 'C'}
# {'pos': array([3638, 3654]), 'lane': 'C'}
# {'pos': array([3639, 3551]), 'lane': 'C'}
# {'pos': array([3639, 3448]), 'lane': 'C'}
# {'pos': array([3639, 3350]), 'lane': 'C'}
# {'pos': array([3639, 3350]), 'lane': 'intersection'}
# {'pos': array([4704, 7242]), 'lane': 'C'}
# {'pos': array([4807, 7257]), 'lane': 'C'}
# {'pos': array([4916, 7257]), 'lane': 'C'}
# {'pos': array([5025, 7257]), 'lane': 'C'}
# {'pos': array([5135, 7257]), 'lane': 'C'}
# {'pos': array([5244, 7257]), 'lane': 'C'}
# {'pos': array([5353, 7257]), 'lane': 'C'}
# {'pos': array([5463, 7257]), 'lane': 'C'}
# {'pos': array([5572, 7257]), 'lane': 'C'}
# {'pos': array([5681, 7257]), 'lane': 'C'}
# {'pos': array([5791, 7257]), 'lane': 'C'}
# {'pos': array([5900, 7257]), 'lane': 'C'}
# {'pos': array([6010, 7257]), 'lane': 'C'}
# {'pos': array([6119, 7257]), 'lane': 'C'}
# {'pos': array([6228, 7257]), 'lane': 'C'}
# {'pos': array([6338, 7257]), 'lane': 'C'}
# {'pos': array([6447, 7257]), 'lane': 'C'}
# {'pos': array([6556, 7257]), 'lane': 'C'}
# {'pos': array([6666, 7257]), 'lane': 'C'}
# {'pos': array([6773, 7257]), 'lane': 'C'}
# {}
# {'pos': array([4704, 7242]), 'lane': 'C'}
# {'pos': array([4690, 7149]), 'lane': 'C'}
# {'pos': array([4690, 7045]), 'lane': 'C'}
# {'pos': array([4690, 6941]), 'lane': 'C'}
# {'pos': array([4690, 6837]), 'lane': 'C'}
# {'pos': array([4690, 6733]), 'lane': 'C'}
# {'pos': array([4690, 6630]), 'lane': 'C'}
# {'pos': array([4690, 6526]), 'lane': 'C'}
# {'pos': array([4690, 6422]), 'lane': 'C'}
# {'pos': array([4690, 6318]), 'lane': 'C'}
# {'pos': array([4690, 6214]), 'lane': 'C'}
# {'pos': array([4690, 6110]), 'lane': 'C'}
# {'pos': array([4690, 6006]), 'lane': 'C'}
# {'pos': array([4690, 5902]), 'lane': 'C'}
# {'pos': array([4690, 5799]), 'lane': 'C'}
# {'pos': array([4690, 5695]), 'lane': 'C'}
# {'pos': array([4690, 5591]), 'lane': 'C'}
# {'pos': array([4690, 5487]), 'lane': 'C'}
# {'pos': array([4690, 5383]), 'lane': 'C'}
# {'pos': array([4690, 5279]), 'lane': 'C'}
# {'pos': array([4690, 5175]), 'lane': 'C'}
# {'pos': array([4690, 5071]), 'lane': 'C'}
# {'pos': array([4690, 4968]), 'lane': 'C'}
# {'pos': array([4690, 4864]), 'lane': 'C'}
# {'pos': array([4690, 4760]), 'lane': 'C'}
# {'pos': array([4690, 4656]), 'lane': 'C'}
# {'pos': array([4690, 4552]), 'lane': 'C'}
# {'pos': array([4690, 4448]), 'lane': 'C'}
# {'pos': array([4690, 4344]), 'lane': 'C'}
# {'pos': array([4690, 4240]), 'lane': 'C'}
# {'pos': array([4690, 4137]), 'lane': 'C'}
# {'pos': array([4690, 4033]), 'lane': 'C'}
# {'pos': array([4690, 3929]), 'lane': 'C'}
# {'pos': array([4690, 3825]), 'lane': 'C'}
# {'pos': array([4690, 3721]), 'lane': 'C'}
# {'pos': array([4690, 3617]), 'lane': 'C'}
# {'pos': array([4690, 3513]), 'lane': 'C'}
# {'pos': array([4690, 3409]), 'lane': 'C'}
# {'pos': array([4714, 3327]), 'lane': 'C'}
# {'pos': array([4714, 3327]), 'lane': 'intersection'}
# {'pos': array([6773, 7257]), 'lane': 'C'}
# {'pos': array([6793, 7161]), 'lane': 'C'}
# {'pos': array([6793, 7056]), 'lane': 'C'}
# {'pos': array([6793, 6953]), 'lane': 'C'}
# {'pos': array([6793, 6849]), 'lane': 'C'}
# {'pos': array([6793, 6745]), 'lane': 'C'}
# {'pos': array([6793, 6640]), 'lane': 'C'}
# {'pos': array([6793, 6536]), 'lane': 'C'}
# {'pos': array([6793, 6432]), 'lane': 'C'}
# {'pos': array([6793, 6328]), 'lane': 'C'}
# {'pos': array([6793, 6224]), 'lane': 'C'}
# {'pos': array([6793, 6119]), 'lane': 'C'}
# {'pos': array([6793, 6015]), 'lane': 'C'}
# {'pos': array([6793, 5911]), 'lane': 'C'}
# {'pos': array([6793, 5807]), 'lane': 'C'}
# {'pos': array([6793, 5703]), 'lane': 'C'}
# {'pos': array([6793, 5598]), 'lane': 'C'}
# {'pos': array([6793, 5494]), 'lane': 'C'}
# {'pos': array([6793, 5390]), 'lane': 'C'}
# {'pos': array([6793, 5286]), 'lane': 'C'}
# {'pos': array([6793, 5182]), 'lane': 'C'}
# {'pos': array([6793, 5078]), 'lane': 'C'}
# {'pos': array([6793, 4973]), 'lane': 'C'}
# {'pos': array([6793, 4869]), 'lane': 'C'}
# {'pos': array([6793, 4765]), 'lane': 'C'}
# {'pos': array([6793, 4661]), 'lane': 'C'}
# {'pos': array([6793, 4557]), 'lane': 'C'}
# {'pos': array([6793, 4452]), 'lane': 'C'}
# {'pos': array([6793, 4348]), 'lane': 'C'}
# {'pos': array([6793, 4244]), 'lane': 'C'}
# {'pos': array([6793, 4140]), 'lane': 'C'}
# {'pos': array([6793, 4036]), 'lane': 'C'}
# {'pos': array([6793, 3931]), 'lane': 'C'}
# {'pos': array([6793, 3827]), 'lane': 'C'}
# {'pos': array([6793, 3723]), 'lane': 'C'}
# {'pos': array([6793, 3619]), 'lane': 'C'}
# {'pos': array([6793, 3515]), 'lane': 'C'}
# {'pos': array([6793, 3410]), 'lane': 'C'}
# {'pos': array([6773, 3315]), 'lane': 'C'}
# {'pos': array([6773, 3315]), 'lane': 'intersection'}
# {'pos': array([1552, 6199]), 'lane': 'C'}
# {'pos': array([1659, 6206]), 'lane': 'C'}
# {'pos': array([1771, 6206]), 'lane': 'C'}
# {'pos': array([1884, 6206]), 'lane': 'C'}
# {'pos': array([1997, 6206]), 'lane': 'C'}
# {'pos': array([2110, 6206]), 'lane': 'C'}
# {'pos': array([2223, 6206]), 'lane': 'C'}
# {'pos': array([2336, 6206]), 'lane': 'C'}
# {'pos': array([2439, 6197]), 'lane': 'C'}
# {}
# {'pos': array([1552, 6199]), 'lane': 'C'}
# {'pos': array([1536, 6099]), 'lane': 'C'}
# {'pos': array([1535, 5994]), 'lane': 'C'}
# {'pos': array([1535, 5888]), 'lane': 'C'}
# {'pos': array([1535, 5782]), 'lane': 'C'}
# {'pos': array([1535, 5676]), 'lane': 'C'}
# {'pos': array([1535, 5570]), 'lane': 'C'}
# {'pos': array([1535, 5464]), 'lane': 'C'}
# {'pos': array([1535, 5358]), 'lane': 'C'}
# {'pos': array([1535, 5252]), 'lane': 'C'}
# {'pos': array([1535, 5146]), 'lane': 'C'}
# {'pos': array([1535, 5040]), 'lane': 'C'}
# {'pos': array([1535, 4934]), 'lane': 'C'}
# {'pos': array([1535, 4828]), 'lane': 'C'}
# {'pos': array([1535, 4722]), 'lane': 'C'}
# {'pos': array([1535, 4616]), 'lane': 'C'}
# {'pos': array([1535, 4510]), 'lane': 'C'}
# {'pos': array([1535, 4404]), 'lane': 'C'}
# {'pos': array([1535, 4298]), 'lane': 'C'}
# {'pos': array([1535, 4192]), 'lane': 'C'}
# {'pos': array([1535, 4086]), 'lane': 'C'}
# {'pos': array([1535, 3980]), 'lane': 'C'}
# {'pos': array([1535, 3874]), 'lane': 'C'}
# {'pos': array([1535, 3768]), 'lane': 'C'}
# {'pos': array([1535, 3662]), 'lane': 'C'}
# {'pos': array([1535, 3556]), 'lane': 'C'}
# {'pos': array([1535, 3450]), 'lane': 'C'}
# {'pos': array([1545, 3349]), 'lane': 'C'}
# {'pos': array([1545, 3349]), 'lane': 'intersection'}
# {'pos': array([2439, 6197]), 'lane': 'C'}
# {'pos': array([2455, 6097]), 'lane': 'C'}
# {'pos': array([2455, 5991]), 'lane': 'C'}
# {'pos': array([2455, 5886]), 'lane': 'C'}
# {'pos': array([2455, 5780]), 'lane': 'C'}
# {'pos': array([2455, 5674]), 'lane': 'C'}
# {'pos': array([2455, 5568]), 'lane': 'C'}
# {'pos': array([2455, 5462]), 'lane': 'C'}
# {'pos': array([2455, 5356]), 'lane': 'C'}
# {'pos': array([2455, 5250]), 'lane': 'C'}
# {'pos': array([2455, 5145]), 'lane': 'C'}
# {'pos': array([2455, 5039]), 'lane': 'C'}
# {'pos': array([2455, 4933]), 'lane': 'C'}
# {'pos': array([2455, 4827]), 'lane': 'C'}
# {'pos': array([2455, 4721]), 'lane': 'C'}
# {'pos': array([2455, 4615]), 'lane': 'C'}
# {'pos': array([2455, 4509]), 'lane': 'C'}
# {'pos': array([2455, 4404]), 'lane': 'C'}
# {'pos': array([2455, 4298]), 'lane': 'C'}
# {'pos': array([2455, 4192]), 'lane': 'C'}
# {'pos': array([2455, 4086]), 'lane': 'C'}
# {'pos': array([2455, 3980]), 'lane': 'C'}
# {'pos': array([2455, 3874]), 'lane': 'C'}
# {'pos': array([2455, 3768]), 'lane': 'C'}
# {'pos': array([2455, 3663]), 'lane': 'C'}
# {'pos': array([2456, 3557]), 'lane': 'C'}
# {'pos': array([2456, 3451]), 'lane': 'C'}
# {'pos': array([2456, 3350]), 'lane': 'C'}
# {'pos': array([2456, 3350]), 'lane': 'intersection'}
# {'pos': array([1545, 3349]), 'lane': 'C'}
# {'pos': array([1636, 3314]), 'lane': 'C'}
# {'pos': array([1757, 3314]), 'lane': 'C'}
# {'pos': array([1877, 3314]), 'lane': 'C'}
# {'pos': array([1997, 3314]), 'lane': 'C'}
# {'pos': array([2118, 3314]), 'lane': 'C'}
# {'pos': array([2238, 3314]), 'lane': 'C'}
# {'pos': array([2358, 3314]), 'lane': 'C'}
# {'pos': array([2456, 3350]), 'lane': 'C'}
# {}
# {'pos': array([1545, 3349]), 'lane': 'C'}
# {'pos': array([1538, 3246]), 'lane': 'C'}
# {'pos': array([1535, 3132]), 'lane': 'C'}
# {'pos': array([1535, 3018]), 'lane': 'C'}
# {'pos': array([1535, 2903]), 'lane': 'C'}
# {'pos': array([1535, 2788]), 'lane': 'C'}
# {'pos': array([1535, 2673]), 'lane': 'C'}
# {'pos': array([1537, 2559]), 'lane': 'C'}
# {'pos': array([1563, 2456]), 'lane': 'C'}
# {'pos': array([1563, 2456]), 'lane': 'intersection'}
# {'pos': array([2456, 3350]), 'lane': 'C'}
# {'pos': array([2544, 3315]), 'lane': 'C'}
# {'pos': array([2656, 3314]), 'lane': 'C'}
# {'pos': array([2768, 3314]), 'lane': 'C'}
# {'pos': array([2880, 3314]), 'lane': 'C'}
# {'pos': array([2991, 3313]), 'lane': 'C'}
# {'pos': array([3103, 3313]), 'lane': 'C'}
# {'pos': array([3214, 3314]), 'lane': 'C'}
# {'pos': array([3326, 3314]), 'lane': 'C'}
# {'pos': array([3438, 3314]), 'lane': 'C'}
# {'pos': array([3550, 3315]), 'lane': 'C'}
# {'pos': array([3639, 3350]), 'lane': 'C'}
# {}
# {'pos': array([3639, 3350]), 'lane': 'C'}
# {'pos': array([3726, 3315]), 'lane': 'C'}
# {'pos': array([3837, 3314]), 'lane': 'C'}
# {'pos': array([3948, 3314]), 'lane': 'C'}
# {'pos': array([4059, 3314]), 'lane': 'C'}
# {'pos': array([4170, 3314]), 'lane': 'C'}
# {'pos': array([4281, 3314]), 'lane': 'C'}
# {'pos': array([4392, 3314]), 'lane': 'C'}
# {'pos': array([4503, 3314]), 'lane': 'C'}
# {'pos': array([4614, 3316]), 'lane': 'C'}
# {'pos': array([4714, 3327]), 'lane': 'C'}
# {}
# {'pos': array([4714, 3327]), 'lane': 'C'}
# {'pos': array([4817, 3314]), 'lane': 'C'}
# {'pos': array([4926, 3314]), 'lane': 'C'}
# {'pos': array([5035, 3314]), 'lane': 'C'}
# {'pos': array([5143, 3314]), 'lane': 'C'}
# {'pos': array([5252, 3314]), 'lane': 'C'}
# {'pos': array([5361, 3314]), 'lane': 'C'}
# {'pos': array([5470, 3314]), 'lane': 'C'}
# {'pos': array([5579, 3314]), 'lane': 'C'}
# {'pos': array([5687, 3314]), 'lane': 'C'}
# {'pos': array([5796, 3314]), 'lane': 'C'}
# {'pos': array([5905, 3314]), 'lane': 'C'}
# {'pos': array([6014, 3314]), 'lane': 'C'}
# {'pos': array([6123, 3314]), 'lane': 'C'}
# {'pos': array([6231, 3314]), 'lane': 'C'}
# {'pos': array([6340, 3314]), 'lane': 'C'}
# {'pos': array([6449, 3314]), 'lane': 'C'}
# {'pos': array([6558, 3314]), 'lane': 'C'}
# {'pos': array([6667, 3314]), 'lane': 'C'}
# {'pos': array([6773, 3315]), 'lane': 'C'}
# {}
# {'pos': array([6773, 3315]), 'lane': 'C'}
# {'pos': array([6793, 3195]), 'lane': 'C'}
# {'pos': array([6793, 3069]), 'lane': 'C'}
# {'pos': array([6793, 2941]), 'lane': 'C'}
# {'pos': array([6793, 2814]), 'lane': 'C'}
# {'pos': array([6793, 2686]), 'lane': 'C'}
# {'pos': array([6792, 2559]), 'lane': 'C'}
# {'pos': array([6757, 2446]), 'lane': 'C'}
# {'pos': array([6757, 2446]), 'lane': 'intersection'}
# {'pos': array([1563, 2456]), 'lane': 'C'}
# {'pos': array([1641, 2404]), 'lane': 'C'}
# {'pos': array([1740, 2394]), 'lane': 'C'}
# {'pos': array([1843, 2394]), 'lane': 'C'}
# {'pos': array([1946, 2394]), 'lane': 'C'}
# {'pos': array([2049, 2394]), 'lane': 'C'}
# {'pos': array([2152, 2394]), 'lane': 'C'}
# {'pos': array([2254, 2394]), 'lane': 'C'}
# {'pos': array([2357, 2394]), 'lane': 'C'}
# {'pos': array([2460, 2394]), 'lane': 'C'}
# {'pos': array([2563, 2394]), 'lane': 'C'}
# {'pos': array([2666, 2394]), 'lane': 'C'}
# {'pos': array([2769, 2394]), 'lane': 'C'}
# {'pos': array([2871, 2394]), 'lane': 'C'}
# {'pos': array([2974, 2394]), 'lane': 'C'}
# {'pos': array([3077, 2394]), 'lane': 'C'}
# {'pos': array([3180, 2394]), 'lane': 'C'}
# {'pos': array([3283, 2394]), 'lane': 'C'}
# {'pos': array([3386, 2394]), 'lane': 'C'}
# {'pos': array([3488, 2394]), 'lane': 'C'}
# {'pos': array([3591, 2394]), 'lane': 'C'}
# {'pos': array([3694, 2394]), 'lane': 'C'}
# {'pos': array([3797, 2394]), 'lane': 'C'}
# {'pos': array([3900, 2394]), 'lane': 'C'}
# {'pos': array([4003, 2394]), 'lane': 'C'}
# {'pos': array([4105, 2394]), 'lane': 'C'}
# {'pos': array([4208, 2394]), 'lane': 'C'}
# {'pos': array([4311, 2394]), 'lane': 'C'}
# {'pos': array([4414, 2394]), 'lane': 'C'}
# {'pos': array([4517, 2394]), 'lane': 'C'}
# {'pos': array([4620, 2394]), 'lane': 'C'}
# {'pos': array([4722, 2394]), 'lane': 'C'}
# {'pos': array([4825, 2394]), 'lane': 'C'}
# {'pos': array([4928, 2394]), 'lane': 'C'}
# {'pos': array([5031, 2394]), 'lane': 'C'}
# {'pos': array([5134, 2394]), 'lane': 'C'}
# {'pos': array([5237, 2394]), 'lane': 'C'}
# {'pos': array([5339, 2394]), 'lane': 'C'}
# {'pos': array([5442, 2394]), 'lane': 'C'}
# {'pos': array([5545, 2394]), 'lane': 'C'}
# {'pos': array([5648, 2394]), 'lane': 'C'}
# {'pos': array([5751, 2394]), 'lane': 'C'}
# {'pos': array([5854, 2394]), 'lane': 'C'}
# {'pos': array([5957, 2394]), 'lane': 'C'}
# {'pos': array([6059, 2394]), 'lane': 'C'}
# {'pos': array([6162, 2394]), 'lane': 'C'}
# {'pos': array([6265, 2394]), 'lane': 'C'}
# {'pos': array([6368, 2394]), 'lane': 'C'}
# {'pos': array([6471, 2394]), 'lane': 'C'}
# {'pos': array([6574, 2394]), 'lane': 'C'}
# {'pos': array([6673, 2401]), 'lane': 'C'}
# {'pos': array([6757, 2446]), 'lane': 'C'}
# {}

# %%
# --- Optional: Visualization ---
plt.imshow(rgbmap)
for idx, p in enumerate(intersections):
    plt.scatter(p[0], p[1], c='red', s=10)

for node_id in G_ped.nodes:
    try:
        pos = G_ped.nodes[node_id]['pos']
        plt.plot(pos[0], pos[1], 'k.', linewidth=0.3)
    except:
        print(node_id)
        continue



plt.title("Equidistant Waypoints with Lane Offsets")
plt.axis('off')
plt.show()

# %%
import pickle

# Save
with open("town01-center.pkl", "wb") as f:
    pickle.dump(G_center, f)

with open("town01-left.pkl", "wb") as f:
    pickle.dump(G_left, f)

with open("town01-right.pkl", "wb") as f:
    pickle.dump(G_right, f)


with open("town01-ped.pkl", "wb") as f:
    pickle.dump(G_right, f)

# %% [markdown]
# # EXPAND GRAPH

# %%
import pickle
# Load
with open("town01-center.pkl", "rb") as f:
    G_base = pickle.load(f)

# %%
def build_semantic_lane_graph(centerline, edge_id=(0,1),
                              lane_offsets=None,
                              lane_types=None,
                              cost_forward_dict=None,
                              cost_cross_dict=None,
                              cost_diag_dict=None,
                              cost_to_intersection=0.1,
                              G=None):
    """
    Add lanes and intersections to an existing graph G (or create a new one).
    
    Parameters:
        G: networkx.DiGraph or None
            Existing graph to update. If None, a new graph is created.
        Other params as before...
    """
    import networkx as nx
    import numpy as np

    if G is None:
        G = nx.DiGraph()

    if lane_offsets is None:
        lane_offsets = [3.5, 0.0, -3.5]
    if lane_types is None:
        lane_types = ["vehicle"] * len(lane_offsets)

    # Same cost dict defaults as before...
    if cost_forward_dict is None:
        cost_forward_dict = {lt: 1.0 for lt in set(lane_types)}
    if cost_cross_dict is None:
        cost_cross_dict = {}
        for lt in set(lane_types):
            cost_cross_dict[(lt, lt)] = 5.0
        for lt1 in set(lane_types):
            for lt2 in set(lane_types):
                if lt1 != lt2:
                    cost_cross_dict[(lt1, lt2)] = 20.0
                    cost_cross_dict[(lt2, lt1)] = 20.0
    if cost_diag_dict is None:
        cost_diag_dict = cost_cross_dict

    edge_label = f"{edge_id[0]}-{edge_id[1]}"
    centerline = np.array(centerline)
    N = len(centerline)

    def compute_offset_points(points, offset_dist):
        offsets = []
        for i in range(len(points)):
            if i == len(points) - 1:
                direction = points[i] - points[i - 1]
            else:
                direction = points[i + 1] - points[i]
            norm_dir = direction / np.linalg.norm(direction)
            perp = np.array([-norm_dir[1], norm_dir[0]])
            offsets.append(points[i] + perp * offset_dist)
        return np.array(offsets)

    lane_coords = [compute_offset_points(centerline, off) for off in lane_offsets]
    lane_names = [f"L{i}" for i in range(len(lane_offsets))]

    # Add nodes if they don't exist yet
    for lane_name, coords, lane_type in zip(lane_names, lane_coords, lane_types):
        for i, pos in enumerate(coords):
            node = f"{edge_label}_{lane_name}_{i}"
            if node not in G:
                G.add_node(node, pos=pos, lane=lane_name, semantic=lane_type)

    # Add edges (vertical, horizontal, diagonal) - just add or overwrite
    for lane_name, lane_type in zip(lane_names, lane_types):
        forward_cost = cost_forward_dict.get(lane_type, 1.0)
        for i in range(N - 1):
            node1 = f"{edge_label}_{lane_name}_{i}"
            node2 = f"{edge_label}_{lane_name}_{i+1}"
            G.add_edge(node1, node2, cost=forward_cost, relation='forward')

    for i in range(N):
        for j in range(len(lane_names) - 1):
            node1 = f"{edge_label}_{lane_names[j]}_{i}"
            node2 = f"{edge_label}_{lane_names[j + 1]}_{i}"
            lt1 = lane_types[j]
            lt2 = lane_types[j + 1]
            cross_cost = cost_cross_dict.get((lt1, lt2), 20.0)
            G.add_edge(node1, node2, cost=cross_cost, relation='horizontal')
            G.add_edge(node2, node1, cost=cross_cost, relation='horizontal')

    for i in range(N - 1):
        for j in range(1, len(lane_names)):
            node_curr = f"{edge_label}_{lane_names[j]}_{i}"
            node_left_next = f"{edge_label}_{lane_names[j - 1]}_{i + 1}"
            lt_curr = lane_types[j]
            lt_left = lane_types[j - 1]
            diag_cost = cost_diag_dict.get((lt_curr, lt_left), 20.0)
            G.add_edge(node_curr, node_left_next, cost=diag_cost, relation='diagonal')
            G.add_edge(node_left_next, node_curr, cost=diag_cost, relation='diagonal')

    # Add intersection nodes only if not present
    start_intersection = f"intersection_{edge_id[0]}"
    end_intersection = f"intersection_{edge_id[1]}"

    if start_intersection not in G:
        G.add_node(start_intersection, pos=centerline[0], lane="intersection", semantic="intersection")
    if end_intersection not in G:
        G.add_node(end_intersection, pos=centerline[-1], lane="intersection", semantic="intersection")

    # Connect lane endpoints to intersections
    for lane_name in lane_names:
        if "sidewalk" in lane_name:
                # Skip connecting sidewalks directly to intersections
                continue  
        start_node = f"{edge_label}_{lane_name}_0"
        end_node = f"{edge_label}_{lane_name}_{N-1}"
        G.add_edge(start_intersection, start_node, cost=cost_to_intersection, relation='intersection')
        G.add_edge(start_node, start_intersection, cost=cost_to_intersection, relation='intersection')
        G.add_edge(end_intersection, end_node, cost=cost_to_intersection, relation='intersection')
        G.add_edge(end_node, end_intersection, cost=cost_to_intersection, relation='intersection')

    return G

# %%
lane_offsets = [40, -40]
lane_types = ["vehicle", "vehicle"]

cost_forward_dict = {
    "vehicle": 1.0,
    "intersection": 1.0,
}

cost_cross_dict = {
    ("vehicle", "vehicle"): 1.5,
    ("vehicle", "sidewalk"): 10.0,
    ("sidewalk", "sidewalk"): 10.0,
    ("sidewalk", "vehicle"): 3.0,
    ("intersection", "vehicle"): 3.0,
}

cost_diag_dict = {
    ("vehicle", "vehicle"): 1.0,
    ("vehicle", "sidewalk"): 5.0,
    ("sidewalk", "sidewalk"): 3.0,
    ("sidewalk", "vehicle"): 5.0
}

# --- Full planning graph ---
G_vehicles = G_intersections.copy()

# --- Main loop ---
for i, j in G_intersections.edges:
    node_a = intersection_nodes[i]
    node_b = intersection_nodes[j]
     # Get path in pixel_graph and sample waypoints
    path = nx.shortest_path(pixel_graph, node_a, node_b)
    waypoints = sample_equidistant_points(path, step=100)

    G_vehicles = build_semantic_lane_graph(waypoints, 
                                  edge_id=(i, j),
                                  lane_offsets=lane_offsets,
                                  lane_types=lane_types,
                                  cost_forward_dict=cost_forward_dict,
                                  cost_cross_dict=cost_cross_dict,
                                  cost_diag_dict=cost_diag_dict,
                                  cost_to_intersection=1.0,
                                  G=G_vehicles)

# %%
lane_offsets = [90, 40, 0, -40, -90]
lane_types = ["sidewalk", "vehicle", "vehicle", "vehicle", "sidewalk"]

cost_forward_dict = {
    "vehicle": 1.0,
    "intersection": 2.0,
    "sidewalk": 3.0,
    
}

cost_cross_dict = {
    ("vehicle", "vehicle"): 1.5,
    ("vehicle", "sidewalk"): 10.0,
    ("sidewalk", "sidewalk"): 10.0,
    ("sidewalk", "vehicle"): 3.0,
    ("intersection", "vehicle"): 3.0,
}

cost_diag_dict = {
    ("vehicle", "vehicle"): 1.0,
    ("vehicle", "sidewalk"): 5.0,
    ("sidewalk", "sidewalk"): 3.0,
    ("sidewalk", "vehicle"): 5.0
}

# --- Full planning graph ---
G_final = G_intersections.copy()

# --- Main loop ---
for i, j in G_intersections.edges:
    node_a = intersection_nodes[i]
    node_b = intersection_nodes[j]
     # Get path in pixel_graph and sample waypoints
    path = nx.shortest_path(pixel_graph, node_a, node_b)
    waypoints = sample_equidistant_points(path, step=100)

    G_final = build_semantic_lane_graph(waypoints, 
                                  edge_id=(i, j),
                                  lane_offsets=lane_offsets,
                                  lane_types=lane_types,
                                  cost_forward_dict=cost_forward_dict,
                                  cost_cross_dict=cost_cross_dict,
                                  cost_diag_dict=cost_diag_dict,
                                  cost_to_intersection=1.0,
                                  G=G_final)

# %%
import matplotlib.pyplot as plt
import networkx as nx

def draw_graph(G):
    plt.figure(figsize=(12, 8))

    # Extract node positions
    pos = {node: data['pos'] for node, data in G.nodes(data=True)}

    # Extract semantic labels for coloring
    semantics = [data.get('semantic', 'unknown') for _, data in G.nodes(data=True)]
    unique_semantics = list(set(semantics))

    # Assign colors to semantics
    colors_map = {
        'vehicle': 'blue',
        'sidewalk': 'green',
        'intersection': 'red',
        'unknown': 'gray'
    }
    # Fallback for unknown semantics
    node_colors = [colors_map.get(sem, 'gray') for sem in semantics]

    # Draw nodes
    nx.draw_networkx_nodes(G, pos, node_color=node_colors, node_size=10, alpha=0.8)

    # Draw edges with light gray color
    nx.draw_networkx_edges(G, pos, alpha=0.4, edge_color='gray')

    # Optional: draw labels for intersections or lane names
    labels = {}
    for node, data in G.nodes(data=True):
        if data.get('semantic') == 'intersection':
            labels[node] = node
    nx.draw_networkx_labels(G, pos, labels, font_size=8, font_color='red')

    plt.axis('off')
    plt.title("Semantic Lane Graph")
    plt.show()

# Usage
draw_graph(G_vehicles)

# %%
with open("town01-vehicles-2lanes-100.pkl", "wb") as f:
    pickle.dump(G_vehicles, f)
